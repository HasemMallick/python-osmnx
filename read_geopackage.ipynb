# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('./data/mynetwork.gpkg')

# %%
gdf.head(5)
# Out:
#       osmid          y           x  street_count highway  \
# 0  53017091  37.826250 -122.247604             3
# 1  53018397  37.824220 -122.247198             3    stop
# 2  53018399  37.824900 -122.246113             3
# 3  53018402  37.825406 -122.245338             3
# 4  53018404  37.825948 -122.244467             3
#
#                       geometry
# 0  POINT (-122.24760 37.82625)
# 1  POINT (-122.24720 37.82422)
# 2  POINT (-122.24611 37.82490)
# 3  POINT (-122.24534 37.82541)
# 4  POINT (-122.24447 37.82595)

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf = gpd.read_file('./data/piedmont_bldgs.gpkg')
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.length
# Out:
# C:\Users\Hasem\AppData\Local\Temp\ipykernel_7980\918143815.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'length' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf.length
# 0       0.000000
# 1       0.002575
# 2       0.001342
# 3       0.001684
# 4       0.001324
#           ...
# 4755    0.000358
# 4756    0.000104
# 4757    0.000344
# 4758    0.000216
# 4759    0.000945
# Length: 4760, dtype: float64
